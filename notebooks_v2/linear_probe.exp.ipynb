# %%
import os
import pandas as pd
import numpy as np
import json
from glob import glob
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# chexomni vs chexzero
df = pd.read_csv('/home/than/DeepLearning/cxr_concept/CheXzero/concepts/results/linear_probing_auc_comparison/sfr_mistral_vs_chexzero_detailed_results.csv')
df_signi = df[df['sfr_mistral_vs_chexzero_p_value'] < 0.01]
df_non_signi = df[df['sfr_mistral_vs_chexzero_p_value'] >= 0.01]
len(df_signi), len(df_non_signi)
df_better = df[df['sfr_mistral_vs_chexzero_diff'] > 0]
df_worse = df[df['sfr_mistral_vs_chexzero_diff'] < 0]
len(df_better), len(df_worse)
df_better
df_worse
# Out:
# (12, 1)
# (9, 4)
#                label  sfr_mistral_mean_auc  sfr_mistral_std_auc  \
# 0        Atelectasis              0.876310             0.000035
# 2      Consolidation              0.905026             0.000098
# 5           Fracture              0.719657             0.000237
# 6        Lung Lesion              0.885620             0.000365
# 7       Lung Opacity              0.933205             0.000042
# 8   Pleural Effusion              0.945339             0.000023
# 10         Pneumonia              0.839347             0.000966
# 11      Pneumothorax              0.894003             0.000237
# 12   Support Devices              0.928360             0.000057
#
#     sfr_mistral_ci_lower  sfr_mistral_ci_upper  sfr_mistral_n_runs  \
# 0               0.876240              0.876354                  20
# 2               0.904934              0.905193                  20
# 5               0.719192              0.720000                  20
# ...

# %%
df['sfr_mistral_mean_auc'].mean()
df['chexzero_mean_auc'].mean()
# Out:
# np.float64(0.8702883846153845)
# np.float64(0.8335981538461539)

# %%
# chexomni vs biomedclip
df = pd.read_csv('/home/than/DeepLearning/cxr_concept/CheXzero/concepts/results/linear_probing_auc_comparison/sfr_mistral_vs_biomedclip_detailed_results.csv')
df_signi = df[df['sfr_mistral_vs_biomedclip_p_value'] < 0.01]
df_non_signi = df[df['sfr_mistral_vs_biomedclip_p_value'] >= 0.01]
len(df_signi), len(df_non_signi)
df_better = df[df['sfr_mistral_vs_biomedclip_diff'] > 0]
df_worse = df[df['sfr_mistral_vs_biomedclip_diff'] < 0]
len(df_better), len(df_worse)
df_better
df_worse
# Out:
# (13, 0)
# (12, 1)
#                          label  sfr_mistral_mean_auc  sfr_mistral_std_auc  \
# 0                  Atelectasis              0.876310             0.000035
# 1                 Cardiomegaly              0.867389             0.000116
# 2                Consolidation              0.905026             0.000098
# 3                        Edema              0.884214             0.000100
# 4   Enlarged Cardiomediastinum              0.727114             0.000323
# 5                     Fracture              0.719657             0.000237
# 6                  Lung Lesion              0.885620             0.000365
# 7                 Lung Opacity              0.933205             0.000042
# 8             Pleural Effusion              0.945339             0.000023
# 10                   Pneumonia              0.839347             0.000966
# 11                Pneumothorax              0.894003             0.000237
# ...

# %%
df['biomedclip_mean_auc'].mean()
# Out:
# np.float64(0.7184289230769232)

# %%
# chexomni vs openaiclip
df = pd.read_csv('/home/than/DeepLearning/cxr_concept/CheXzero/concepts/results/linear_probing_auc_comparison/sfr_mistral_vs_openai_clip_detailed_results.csv')
df_signi = df[df['sfr_mistral_vs_openai_clip_p_value'] < 0.01]
df_non_signi = df[df['sfr_mistral_vs_openai_clip_p_value'] >= 0.01]
len(df_signi), len(df_non_signi)
df_better = df[df['sfr_mistral_vs_openai_clip_diff'] > 0]
df_worse = df[df['sfr_mistral_vs_openai_clip_diff'] < 0]
len(df_better), len(df_worse)
df_better
df_worse
# Out:
# (13, 0)
# (13, 0)
#                          label  sfr_mistral_mean_auc  sfr_mistral_std_auc  \
# 0                  Atelectasis              0.876310             0.000035
# 1                 Cardiomegaly              0.867389             0.000116
# 2                Consolidation              0.905026             0.000098
# 3                        Edema              0.884214             0.000100
# 4   Enlarged Cardiomediastinum              0.727114             0.000323
# 5                     Fracture              0.719657             0.000237
# 6                  Lung Lesion              0.885620             0.000365
# 7                 Lung Opacity              0.933205             0.000042
# 8             Pleural Effusion              0.945339             0.000023
# 9                Pleural Other              0.908165             0.000207
# 10                   Pneumonia              0.839347             0.000966
# ...

# %%
df['openai_clip_mean_auc'].mean()
# Out:
# np.float64(0.676027)
